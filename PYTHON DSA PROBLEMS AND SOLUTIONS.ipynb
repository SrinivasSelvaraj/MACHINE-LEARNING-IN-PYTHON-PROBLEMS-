# %% [markdown]
# <a href="https://colab.research.google.com/github/SrinivasSelvaraj/MACHINE-LEARNING-IN-PYTHON-PROBLEMS-/blob/main/PYTHON%20DSA%20PROBLEMS%20AND%20SOLUTIONS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Write a python program to load the data stored in a csv data file sampledata_orders.csv in a pandas dataframe and perform the following operations.
#
# 1. print the top 5 row and top 10 row
# 2. print all column names
# 3. print all row index ranges
# 4. print the order quantity column (top 5 values)
# 5. print the sales column (top 10 values)
# 6. print the row with id:50
# 7. print the 3rd row
# 8. print the order quantity, sales, discount and profit of the 2nd, 4th, 6th and 8th row
# 9. print the order quantity, sales and profit of order with discount >10%
# 10. print the production cost(production cost=sales-profit)

# %%
 #1
import pandas as pd
data=pd.read_csv("/content/sampledata_orders.csv")
display(data.head(n=5))
print("\n")
display(data.head(n=10))
# Out:
#    Row ID  Order ID  ... Product Base Margin   Ship Date
# 0       1         3  ...                0.80  10/20/2010
# 1      49       293  ...                0.58   10/2/2012
# 2      50       293  ...                0.39   10/3/2012
# 3      80       483  ...                0.58   7/12/2011
# 4      85       515  ...                0.50   8/30/2010
#
# [5 rows x 21 columns]
#    Row ID  Order ID  ... Product Base Margin   Ship Date
# 0       1         3  ...                0.80  10/20/2010
# 1      49       293  ...                0.58   10/2/2012
# 2      50       293  ...                0.39   10/3/2012
# 3      80       483  ...                0.58   7/12/2011
# 4      85       515  ...                0.50   8/30/2010
# 5      86       515  ...                0.37   8/30/2010
# 6      97       613  ...                0.38   6/17/2011
# 7      98       613  ...                 NaN   6/18/2011
# 8     103       643  ...                 NaN   3/25/2011
# ...

# %%
 #2
import pandas as pd
data=pd.read_csv("/content/sampledata_orders.csv")
display(data.columns)
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
#3
import pandas as pd
data=pd.read_csv("/content/sampledata_orders.csv")
display(data.index)
# Out:
# RangeIndex(start=0, stop=8399, step=1)

# %%
#4
import pandas as pd
data=pd.read_csv("/content/sampledata_orders.csv")
display(data["Order Quantity"].head(5))
# Out:
# 0     6
# 1    49
# 2    27
# 3    30
# 4    19
# Name: Order Quantity, dtype: int64

# %%
#5
import pandas as pd
data=pd.read_csv("/content/sampledata_orders.csv")
display(data["Sales"].head(10))
# Out:
# 0      261.5400
# 1    10123.0200
# 2      244.5700
# 3     4965.7595
# 4      394.2700
# 5      146.6900
# 6       93.5400
# 7      905.0800
# 8     2781.8200
# 9      228.4100
# Name: Sales, dtype: float64

# %%
#6
import pandas as pd
data=pd.read_csv("/content/sampledata_orders.csv")
display(data[data["Row ID"]==50])
# Out:
#    Row ID  Order ID  ... Product Base Margin  Ship Date
# 2      50       293  ...                0.39  10/3/2012
#
# [1 rows x 21 columns]

# %%
#7
import pandas as pd
data=pd.read_csv("/content/sampledata_orders.csv")
display(data.iloc[2])
# Out:
# Row ID                                                                50
# Order ID                                                             293
# Order Date                                                     10/1/2012
# Order Priority                                                      High
# Order Quantity                                                        27
# Sales                                                             244.57
# Discount                                                            0.01
# Ship Mode                                                    Regular Air
# Profit                                                             46.71
# Unit Price                                                          8.69
# Shipping Cost                                                       2.99
# Customer Name                                               Barry French
# Province                                                         Nunavut
# ...

# %%
#8
#print the order quantity, sales, discount and profit of the 2nd, 4th, 6th and 8th row
import pandas as pd
data=pd.read_csv("/content/sampledata_orders.csv")
data.loc[[1,3,5,7],["Order Quantity","Sales","Discount","Profit"]]
# Out:
#    Order Quantity       Sales  Discount   Profit
# 1              49  10123.0200      0.07   457.81
# 3              30   4965.7595      0.08  1198.97
# 5              21    146.6900      0.05     4.43
# 7              22    905.0800      0.09   127.70

# %%
#9
import pandas as pd
data=pd.read_csv("/content/sampledata_orders.csv")
data[data["Discount"]>0.1][["Order Quantity","Sales","Discount","Profit"]]
# Out:
#       Order Quantity    Sales  Discount  Profit
# 18                11  663.784      0.25 -481.04
# 237               22  338.520      0.21  -17.75
# 1321              43  586.110      0.11   98.44
# 1383               1   27.960      0.17   -9.13
# 1454              49  651.900      0.16  -74.51

# %%
#10
import pandas as pd
data=pd.read_csv("/content/sampledata_orders.csv")
data["Sales"]-data["Profit"]
# Out:
# 0         474.7900
# 1        9665.2100
# 2         197.8600
# 3        3766.7895
# 4         363.3300
# 5         142.2600
# 6         147.5800
# 7         777.3800
# 8        3477.0800
# 9         454.7700
# 10        363.7000
# 11        138.8900
# 12        582.1200
# 13       1359.8700
# 14         85.3300
# 15       1032.5800
# 16        154.4600
# 17       4021.5100
# 18       1144.8240
# 19        846.5840
# 20       2167.3405
# 21         32.1100
# 22        103.2500
# 23        684.7100
# 24        329.5400
# 25         75.1400
# 26         62.3400
# 27      12575.8400
# 28        375.9300
# 29        236.3300
# 30        112.5700
# 31        811.6500
# 32        142.0600
# 33        504.9970
# 34        825.8300
# 35       5320.4700
# 36        427.9400
# 37       5505.8900
# 38        388.7000
# 39      10799.6000
# 40         54.4900
# 41        374.9700
# 42       1000.4840
# 43         13.4400
# 44        465.1900
# 45       1314.3015
# 46        101.8700
# ...

# %% [markdown]
# 2. Download the train.csv dataset. As the name says it is a .csv file. The file contains information regarding loans given or refused to applicants. Information on the gender, marital status, education, work and income of the applicant is reported alongside the amount and length of the loan and credit history (i.e. 0 if no previous loan was given, 1 otherwise). Open it in a text editor or excel and inspect it first. Then, answer the following questions (if you have any doubts check here): Load it into a pandas DataFrame. (use column Loan_ID as index. Hint: use parm index_col).
#
# ###I.	Get an idea of the data by visualizing its first 5 entries;
# ###II.	How many total entries are present in the file and How many column are there in the file? How many males and females?
# ###III.	What is the average applicant income? How many Females have an income > than the average?
# ###IV.	How many loans have been given (i.e. Loan_Status equals Y)? What is the percentage of the loans given and that of the loans refused?
# ###V.	What is the percentage of given/refused loans in the case of married people?
# ###VI.	What is the percentage of given/refused loans in the case of applicants with positive credit history (i.e. Credit_History equals 1)?

# %%
#Visualize first 5 entries
import pandas as pd
train=pd.read_csv("/content/train.csv")
train.head()
# Out:
#     Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 0  LP001002   Male      No  ...            1.0         Urban           Y
# 1  LP001003   Male     Yes  ...            1.0         Rural           N
# 2  LP001005   Male     Yes  ...            1.0         Urban           Y
# 3  LP001006   Male     Yes  ...            1.0         Urban           Y
# 4  LP001008   Male      No  ...            1.0         Urban           Y
#
# [5 rows x 13 columns]

# %%
#How many total entries and columns are there in the file?
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
#How many males and females?
train["Gender"].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
#What is the average applicant income
avg_applicant_income =  train["ApplicantIncome"].mean()
avg_applicant_income
# Out:
# 5403.459283387622

# %%
#How many females have an income > than the average
len(train[(train["Gender"] == "Female") & (train["ApplicantIncome"] > avg_applicant_income)])
# Out:
# 21

# %%
#How many loans have been gives (that is loan_status equals to Y)
len(train["Loan_Status"] == "Y")
# Out:
# 614

# %%
# what is the percentage of the loans given and that of the loans refused
train["Loan_Status"].value_counts(normalize=True) * 100
# Out:
# Y    68.729642
# N    31.270358
# Name: Loan_Status, dtype: float64

# %%
#What is the percentage of give/refused loans in the case of married people
train.loc[train["Married"] == "Yes", "Loan_Status"].value_counts(normalize=True) * 100
# Out:
# Y    71.60804
# N    28.39196
# Name: Loan_Status, dtype: float64

# %%
#What is the percentage of given/refused loans in the case of applicant with positive credit history (that is credit_history equals 1)
train.loc[train["Credit_History"] == 1, "Loan_Status"].value_counts(normalize=True) * 100
# Out:
# Y    79.578947
# N    20.421053
# Name: Loan_Status, dtype: float64

# %% [markdown]
# ##EXPERIMENT 1.2

# %% [markdown]
# Download the train.csv dataset. As the name says it is a .csv file. The file contains information regarding loans given or refused to applicants information on the gender, martial status,education, work and income of the applicant is reported alongside the amount and length of the loan and credit history. open it in a text editor or excel and inspect it first. Then ,answer the following question.: Load it into a pandas DataFrame
#
# i. get an idea of the data by visualizing its first 5 enteries;
#
# ii. How many total entries are present in the file and How many column are there in the file?
#
# iii. What is the average applicant income?How many females have an income > than the average?
#
# iv. How many loans have been given? WHat is the percentage of the loans given and that of the loans refused?
#
# v. What is the percentage of given/refused loans in the case of married people?
#
# vi. What is the percentage of given/refused loans in the case of applicants with positive credit history?

# %%
#1
import pandas as pd
df=pd.read_csv('/content/train.csv',index_col='Loan_ID')
df.head()
# Out:
#          Gender Married Dependents  ... Credit_History Property_Area  Loan_Status
# Loan_ID                             ...
# LP001002   Male      No          0  ...            1.0         Urban            Y
# LP001003   Male     Yes          1  ...            1.0         Rural            N
# LP001005   Male     Yes          0  ...            1.0         Urban            Y
# LP001006   Male     Yes          0  ...            1.0         Urban            Y
# LP001008   Male      No          0  ...            1.0         Urban            Y
#
# [5 rows x 12 columns]

# %%
#2
entries=df.shape[0] #row entry
col=df.shape[1] # column entry
print("the total number of entries is {}".format(entries))
print("the total number of column is {}".format(col))
print(df['Gender'].value_counts())
# Out:
# the total number of entries is 614
# the total number of column is 12
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
#3
avg_income=df['ApplicantIncome'].mean()
print('the average income is {}'.format(avg_income))
female=df[df['Gender']=='Female']
f=female[female['ApplicantIncome']>avg_income][['Gender','ApplicantIncome']]
print('female applicants with income higher than average {}'.format(len(f)))
print(f)
# Out:
# the average income is 5403.459283387622
# female applicants with income higher than average 21
#           Gender  ApplicantIncome
# Loan_ID
# LP001186  Female            11500
# LP001392  Female             7451
# LP001422  Female            10408
# LP001516  Female            14866
# LP001519  Female            10000
# LP001708  Female            10000
# LP001776  Female             8333
# LP001871  Female             7200
# LP001945  Female             5417
# LP002142  Female             5500
# LP002194  Female            15759
# LP002231  Female             6000
# LP002301  Female             7441
# LP002377  Female             8624
# LP002393  Female            10047
# LP002407  Female             7142
# LP002582  Female            17263
# LP002634  Female            13262
# LP002731  Female            18165
# LP002813  Female            19484
# LP002959  Female            12000

# %%
#4
df['Loan_Status'].value_counts()
yes=df['Loan_Status'].value_counts()[0]
total =df.shape[0]
print("percentage of loan approved is",yes/total *100)
# Out:
# percentage of loan approved is 68.72964169381108

# %%
#5
m=df[df['Married']=='Yes']
myes=m['Loan_Status'].value_counts()[0] #approved
total=len(df[df["Married"]=='Yes'])
print('percentage of loan approvals in m',myes/total*100)
No=m['Loan_Status'].value_counts()[1]
print('Percentage of loan rejected :',No/total*100)
# Out:
# percentage of loan approvals in m 71.60804020100502
# Percentage of loan rejected : 28.391959798994975

# %%
#6
yes=df['Loan_Status'].value_counts()[0]
total=len(df[df['Credit_History']==1])
print("percentage of loans approved is :",(yes/total)*100)
No=df['Loan_Status'].value_counts()[1]
No/total*100
print('Percentage of loan rejected :',(No/total)*100)
# Out:
# percentage of loans approved is : 88.8421052631579
# Percentage of loan rejected : 40.421052631578945

# %%
pd.set_option('display.max_rows', None)
df = pd.read_csv("/content/train.csv")
print(df)
# Out:
#       Loan_ID  Gender Married  ... Credit_History Property_Area Loan_Status
# 0    LP001002    Male      No  ...            1.0         Urban           Y
# 1    LP001003    Male     Yes  ...            1.0         Rural           N
# 2    LP001005    Male     Yes  ...            1.0         Urban           Y
# 3    LP001006    Male     Yes  ...            1.0         Urban           Y
# 4    LP001008    Male      No  ...            1.0         Urban           Y
# 5    LP001011    Male     Yes  ...            1.0         Urban           Y
# 6    LP001013    Male     Yes  ...            1.0         Urban           Y
# 7    LP001014    Male     Yes  ...            0.0     Semiurban           N
# 8    LP001018    Male     Yes  ...            1.0         Urban           Y
# 9    LP001020    Male     Yes  ...            1.0     Semiurban           N
# 10   LP001024    Male     Yes  ...            1.0         Urban           Y
# ...

# %% [markdown]
# ##EXPERIMENT 1.3

# %% [markdown]
# Download the diamonds.csv dataset. As the name says it is a .csv file. The file contains information regarding diamonds details of Laisha diamond shop. Open it in a text editor or excel and inspect it first. Write a python program to load the data stored in a csv file diamonds.csv in a pandas DataFrame and perform the following operations.
#
#
#
# 1.find carat weight at least 0.3 and write this detail into cart.csv file
#
# 2.find total price of cart weight at maximum 0.3
#
# 3.Sort the ‘carat’ column by ascending and descending order.
#
# 4.Print the premium diamond details
#
# 5.Find the most expensive  diamond whose color is D

# %%
import pandas as pd
df=pd.read_csv('/content/diamonds.csv')
sample=df[df["carat"]>=0.3]
sample.to_csv('cart.csv')

# %%
tot=df[df["carat"]<=0.3]
tot['price'].sum()
# Out:
# 2635135

# %%
r=df.sort_values('carat')
print(r)
r=df.sort_values('carat',ascending=False)
print(r)
# Out:
#        carat      cut color clarity  depth  table  price      x      y     z
# 31593   0.20  Premium     E     VS2   61.1   59.0    367   3.81   3.78  2.32
# 31597   0.20    Ideal     D     VS2   61.5   57.0    367   3.81   3.77  2.33
# 31596   0.20  Premium     F     VS2   62.6   59.0    367   3.73   3.71  2.33
# 31595   0.20    Ideal     E     VS2   59.7   55.0    367   3.86   3.84  2.30
# 31594   0.20  Premium     E     VS2   59.7   62.0    367   3.84   3.80  2.28
# ...      ...      ...   ...     ...    ...    ...    ...    ...    ...   ...
# 25999   4.01  Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 25998   4.01  Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# 27130   4.13     Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 27630   4.50     Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27415   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
#
# [53940 rows x 10 columns]
# ...

# %%
pre=df.groupby('cut')
pre.get_group('Premium')
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 12      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 14      0.20  Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# 15      0.32  Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53928   0.79  Premium     E     SI2   61.4   58.0   2756  6.03  5.96  3.68
# 53930   0.71  Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
#
# [13791 rows x 10 columns]

# %%
color=df.groupby('color')
a=color.get_group('D')
a['price'].max()
# Out:
# 18693
