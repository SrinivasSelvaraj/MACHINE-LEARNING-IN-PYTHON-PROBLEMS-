# %% [markdown]
# <a href="https://colab.research.google.com/github/SrinivasSelvaraj/MACHINE-LEARNING-IN-PYTHON-PROBLEMS-/blob/main/PROBLEMS%20ON%20DATA%20VISUALISATION%20USING%20PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##data visualisation

# %%
import matplotlib.pyplot as plt
x1=[1,2,3,4]
y1=[2,1,3,2]
plt.plot(x1,y1)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Simple Line Plot')
plt.plot(x1,y1,'r*')#red color and *marker
x2=[1,2,3,4]
y2=[2,1,3,2]
plt.plot(x2,y2,'^g-.')#marker=^,color='green',linestyle---
plt.show()

# %% [markdown]
# Plot line graph with red color'o' marker using first 10 rows of sales data

# %%
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv("/content/sampledata_orders.csv")
data=data.head(10)
x=data['Order Quantity'].sort_values()
y=data['Sales']
plt.xlabel('Order quantity')
plt.ylabel('Sales')
plt.plot(x,y,marker='o',color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import math
x =np.arange(1,5)
plt.subplot(2,2,1)
plt.plot(x,x*x)
plt.title("SQUARE")
plt.subplot(2,2,2)
plt.plot(x,np.sqrt(x))
plt.title("SQUARE ROOT")
# Out:
# Text(0.5, 1.0, 'SQUARE ROOT')

# %%
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv("/content/sampledata_orders.csv")
x=data['Order Quantity']
y=data['Shipping Cost']
plt.xlabel('Order Quantity')
plt.ylabel('Shipping Cost')
plt.bar(x,y)
plt.show()

# %% [markdown]
# 1.Write a python program to perform the following operations
#
# Import the Matplotlib Library
#
# Declare two variable x1=[1,2,3,4] and y1=[2,1,3,2].
#
# Set the x label as “x axis”
#
# Set the ylabel as “y axis”
#
# Set the title of the plot as “Simple Line Plot”
#
# Plot the graph
#
# Declare two variable x2=[1,2,3,4] and y2=[2,1,3,2]
#
# Plot the values of x1 and y1, x2 and y2 in the same graph.
#
# For x1, y1 : Use Red color normal lines and * Markers
#
# For X2, Y2, Use Green Color dashed line and ^ Markers

# %%
import matplotlib.pyplot as plt#1
x1=[1,2,3,4]#2
y1=[2,1,3,2]
plt.xlabel('X Axis')#3
plt.ylabel('Y Axis')#4
plt.title("Simple Line Plot")#5
plt.plot(x1,y1)#6
x2=[2,4,5,6]#7
y2=[2,3,4,5]
plt.plot(x2,y2)
plt.plot(x1,y1,'r-*')#8
plt.plot(x2,y2,'g--^')

# %% [markdown]
# 2.	Write a python program to plot the square,square root, exponential and log functions using a 2 x 2 subplot

# %%
import matplotlib.pyplot as plt
import numpy as np
fig,a=plt.subplots(2,2)
x=np.arange(1,5)
a[0][0].plot(x,x*x)
a[0][0].set_title("Square")

a[0][1].plot(x,np.sqrt(x))
a[0][1].set_title("Square root")

a[1][0].plot(x,np.exp(x))
a[1][0].set_title("Exponential")

a[1][1].plot(x,np.log(x))
a[1][0].set_title("Log Functions")
# Out:
# Text(0.5, 1.0, 'Log Functions')

# %% [markdown]
# 3.	Write a Python Program to read the orders dataset and plot a bar graph between the Order Quantity and Shipping Cost parameters

# %%
import pandas as pd
orders=pd.read_csv("/content/sampledata_orders.csv")
orders.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
plt.bar(orders['Order Quantity'],orders['Shipping Cost'])
fig = plt.figure() # new figure
ax = fig.add_axes([0,0,1,1])
ax.bar(orders['Order Quantity'],orders['Shipping Cost'], color='r')
plt.xlabel('Order Quanity')
plt.ylabel('Shipping Cost')
plt.show()

# %% [markdown]
# 4.	For the orders dataset plot the Order Quantity Vs Sales

# %%
fig = plt.figure() # new figure
ax = fig.add_axes([0,0,1,1])
ax.bar(orders['Order Quantity'],orders['Sales'], color='m')
plt.xlabel('Order Quanity')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# 5.	Visualize the Order Priority series using a Histogram. Set the Bin Size to 10

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax1.hist(orders['Order Priority'],width=0.1,color='black',bins=10)
plt.show()

# %% [markdown]
# 6.	Visualize Product Base Margin and Sales using a scatter plot. Set the Color to Red

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.scatter(orders['Product Base Margin'],orders['Sales'], color='purple')
plt.xlabel('Product Base Margin')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# 7.	Load the Iris dataset and plot the petal length using a distance plot as a Histogram using seaborn

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %% [markdown]
# 8

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset('iris')
sns.displot(df['petal_length'])
plt.show()

# %% [markdown]
# #9.Plot the Petal Length and Petal Width using a Joint Plot using seaborn

# %%
sns.jointplot(x='petal_length',y='petal_width',data=df)
plt.show()

# %%
sns.jointplot(x='sepal_width',y='petal_width',data=df)
plt.show()

# %% [markdown]
# #10.	Plot the Species using pair plot

# %%
sns.pairplot(df,hue='species')
plt.show()

# %% [markdown]
# #11.	Plot the Species and Petal Length using Strip Plot

# %%
sns.stripplot(x='species',y='petal_length',data=df)
plt.show()

# %% [markdown]
# #12.Plot the Species and Petal Length using Swarm Plot

# %%
sns.swarmplot(x='species',y='petal_length',data=df)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
